# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# 0               False  Texas, United States 2023-06-16 13:44:15
# 1               False                Mexico 2023-01-14 13:18:07
# 2               False               Germany 2023-10-10 13:14:55
# 3               False  Texas, United States 2023-07-04 13:01:41
# 4               False                 Sudan 2023-08-07 14:29:36
#
#    job_no_degree_mention  job_health_insurance    job_country salary_rate  \
# 0                  False                 False  United States        None
# 1                  False                 False         Mexico        None
# 2                  False                 False        Germany        None
# 3                   True                 False  United States        None
# 4                  False                 False          Sudan        None
#
#    salary_year_avg  salary_hour_avg                  company_name  \
# 0              NaN              NaN          Boehringer Ingelheim
# 1              NaN              NaN    Hewlett Packard Enterprise
# 2              NaN              NaN      ALPHA Augmented Services
# 3              NaN              NaN  Southwest Research Institute
# 4              NaN              NaN               Kristina Daniel
#
#                                           job_skills  \
# 0                                               None
# 1  ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2  ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3  ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 4  ['bash', 'python', 'oracle', 'aws', 'ansible',...
#
#                                      job_type_skills
# 0                                               None
# 1  {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2  {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3  {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4  {'cloud': ['oracle', 'aws'], 'other': ['ansibl...

# %%
df.tail()
# Out:
#           job_title_short                                          job_title  \
# 785736  Software Engineer                                    DevOps Engineer
# 785737       Data Analyst                                   CRM Data Analyst
# 785738   Business Analyst                     Commercial Analyst - Start Now
# 785739      Data Engineer  Principal Associate, Data Engineer (Remote-Eli...
# 785740  Software Engineer                                 AWS System Analyst
#
#                                job_location                    job_via  \
# 785736                            Singapura        melalui Trabajo.org
# 785737                   Bad Rodach, Jerman  melalui BeBee Deutschland
# 785738                             Malaysia           melalui Ricebowl
# 785739  Newark, New Jersey, Amerika Serikat        melalui Recruit.net
# 785740                                India             melalui Trigyn
#
#        job_schedule_type  job_work_from_home search_location  \
# 785736   Pekerjaan tetap               False       Singapore
# 785737   Pekerjaan tetap               False         Germany
# 785738   Pekerjaan tetap               False        Malaysia
# 785739   Pekerjaan tetap               False           Sudan
# 785740   Pekerjaan tetap               False           India
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 785736 2023-03-13 06:16:16                  False                 False
# 785737 2023-03-12 06:18:18                  False                 False
# 785738 2023-03-12 06:32:36                  False                 False
# 785739 2023-03-12 06:32:15                  False                 False
# 785740 2023-03-13 06:16:31                  False                 False
#
#        job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 785736   Singapore        None              NaN              NaN
# 785737     Germany        None              NaN              NaN
# 785738    Malaysia        None              NaN              NaN
# 785739       Sudan        None              NaN              NaN
# 785740       India        None              NaN              NaN
#
#                               company_name  \
# 785736  CAREERSTAR INTERNATIONAL PTE. LTD.
# 785737                    HABA FAMILYGROUP
# 785738               Lendlease Corporation
# 785739                         Capital One
# 785740                              Trigyn
#
#                                                job_skills  \
# 785736  ['bash', 'python', 'perl', 'linux', 'unix', 'k...
# 785737                     ['sas', 'sas', 'sql', 'excel']
# 785738                            ['powerpoint', 'excel']
# 785739  ['python', 'go', 'nosql', 'sql', 'mongo', 'she...
# 785740                                    ['aws', 'flow']
#
#                                           job_type_skills
# 785736  {'os': ['linux', 'unix'], 'other': ['kubernete...
# 785737  {'analyst_tools': ['sas', 'excel'], 'programmi...
# 785738         {'analyst_tools': ['powerpoint', 'excel']}
# 785739  {'cloud': ['aws', 'snowflake', 'azure', 'redsh...
# 785740              {'cloud': ['aws'], 'other': ['flow']}

# %%
df.sample(10)
# Out:
#                   job_title_short  \
# 518701           Business Analyst
# 265110  Machine Learning Engineer
# 329236              Data Engineer
# 212928             Data Scientist
# 648733              Data Engineer
# 653247       Senior Data Engineer
# 212277             Data Scientist
# 766570           Business Analyst
# 456081        Senior Data Analyst
# 508940       Senior Data Engineer
#
#                                                 job_title  \
# 518701  Alternance - Chargé.e de gestion Reporting et ...
# 265110                                  MLOPS AI Engineer
# 329236                                Azure Data Engineer
# 212928                                     Data Scientist
# 648733                                 Lead Data Engineer
# 653247  Sr. Data Engineer, Cross Product Change Servic...
# 212277                                  Database Engineer
# 766570               Senior Business Intelligence Analyst
# 456081  Forensics and Litigation Services Senior Assoc...
# 508940       (Senior) Data Engineer (m/w/d) in Düsseldorf
#
#                job_location               job_via job_schedule_type  \
# 518701     Toulouse, France          via LinkedIn         Full-time
# 265110      Shanghai, China       via Trabajo.org         Full-time
# 329236           London, UK       via Recruit.net         Full-time
# 212928        Cambridge, UK         via WDHN Jobs         Full-time
# 648733        Nashville, TN          via JobServe         Full-time
# 653247           Newark, DE          via LinkedIn         Full-time
# 212277  Panama City, Panama   via LinkedIn Panamá         Full-time
# 766570        Charlotte, NC  via Jobs Trabajo.org         Full-time
# 456081           Dallas, TX          via LinkedIn         Full-time
# 508940  Düsseldorf, Germany          via LinkedIn         Full-time
#
#         job_work_from_home            search_location     job_posted_date  \
# 518701               False                     France 2023-06-09 11:20:42
# 265110               False                      China 2023-10-23 07:49:25
# 329236               False             United Kingdom 2023-02-12 23:39:03
# 212928               False             United Kingdom 2023-04-05 22:19:41
# 648733               False  California, United States 2023-08-11 12:09:52
# 653247               False                      Sudan 2023-02-18 10:36:47
# 212277               False                     Panama 2023-11-22 23:00:54
# 766570               False                    Georgia 2023-08-25 02:05:22
# 456081               False       Texas, United States 2023-07-20 14:02:06
# 508940               False                    Germany 2023-05-17 11:41:01
#
#         job_no_degree_mention  job_health_insurance     job_country  \
# 518701                  False                 False          France
# 265110                  False                 False           China
# 329236                   True                 False  United Kingdom
# 212928                  False                 False  United Kingdom
# 648733                   True                 False   United States
# 653247                  False                  True           Sudan
# 212277                   True                 False          Panama
# 766570                   True                 False   United States
# 456081                  False                 False   United States
# 508940                   True                 False         Germany
#
#        salary_rate  salary_year_avg  salary_hour_avg          company_name  \
# 518701        None              NaN              NaN  Vitesco Technologies
# 265110        None              NaN              NaN             Accenture
# 329236        None              NaN              NaN       Jefferson Frank
# 212928        None              NaN              NaN         Umbilical Ltd
# 648733        None              NaN              NaN            TEKsystems
# 653247        None              NaN              NaN  JPMorgan Chase & Co.
# 212277        None              NaN              NaN            Smartmatic
# 766570        None              NaN              NaN           BrightSpeed
# 456081        None              NaN              NaN                Weaver
# 508940        None              NaN              NaN          BearingPoint
#
#                                                job_skills  \
# 518701                       ['power bi', 'sap', 'excel']
# 265110                                               None
# 329236  ['python', 'sql', 'azure', 'databricks', 'pysp...
# 212928  ['numpy', 'pandas', 'keras', 'scikit-learn', '...
# 648733  ['sql', 'python', 'aws', 'redshift', 'aurora',...
# 653247     ['sql', 'nosql', 'tableau', 'qlik', 'alteryx']
# 212277    ['sql', 'bash', 'postgresql', 'oracle', 'unix']
# 766570          ['power bi', 'ssrs', 'tableau', 'looker']
# 456081       ['sql', 'sql server', 'tableau', 'power bi']
# 508940  ['sql', 'python', 'java', 'scala', 'aws', 'azu...
#
#                                           job_type_skills
# 518701    {'analyst_tools': ['power bi', 'sap', 'excel']}
# 265110                                               None
# 329236  {'cloud': ['azure', 'databricks'], 'libraries'...
# 212928  {'libraries': ['numpy', 'pandas', 'keras', 'sc...
# 648733  {'cloud': ['aws', 'redshift', 'aurora'], 'libr...
# 653247  {'analyst_tools': ['tableau', 'qlik', 'alteryx...
# 212277  {'cloud': ['oracle'], 'databases': ['postgresq...
# 766570  {'analyst_tools': ['power bi', 'ssrs', 'tablea...
# 456081  {'analyst_tools': ['tableau', 'power bi'], 'da...
# 508940  {'cloud': ['aws', 'azure'], 'libraries': ['had...

# %% [markdown]
# ## `copy()`

# %%
dataset = load_dataset('lukebarousse/data_jobs')
df_original = dataset['train'].to_pandas()

# %%
df_altered = df_original

# %%
df_altered.loc[:5, 'salary_year_avg']
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# Name: salary_year_avg, dtype: float64

# %%
median_salary = df_altered['salary_year_avg'].median()

median_salary
# Out:
# 115000.0

# %%
df_altered['salary_year_avg'] = df_altered['salary_year_avg'].fillna(median_salary)

df_altered.loc[:5, 'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %%
df_original.loc[:5, 'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %%
id(df_original)
# Out:
# 2842184903696

# %%
id(df_altered)
# Out:
# 2842184903696

# %%
id(df_original) == id(df_altered)
# Out:
# True

# %%
dataset = load_dataset('lukebarousse/data_jobs')
df_original = dataset['train'].to_pandas()

# %%
df_altered = df_original.copy()

# %%
print('ID of df_original:           ', id(df_original))
print('ID of df_altered:            ', id(df_altered))
print('Are the two dataframes the same?', id(df_original) == id(df_altered))
# Out:
# ID of df_original:            2842689351504
# ID of df_altered:             2842689454544
# Are the two dataframes the same? False

# %%
median_salary = df_altered['salary_year_avg'].median()

df_altered['salary_year_avg'] = df_altered['salary_year_avg'].fillna(median_salary)

df_altered.loc[:5, 'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %%
df_original.loc[:5, 'salary_year_avg']
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# Name: salary_year_avg, dtype: float64
