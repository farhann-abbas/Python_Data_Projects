# %%
# Importing Libraries
import ast
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# Filter for Data Analyst data
df_DA = df[df['job_title_short'] == 'Data Analyst'].copy()

# %% [markdown]
# ## Customizing our chart from `12_Exercise_Trending_Skills.ipynb`

# %%
df_DA = df[df['job_title_short'] == 'Data Analyst'].copy()
# create a new column for month number
df_DA['job_posted_month_no'] = df_DA['job_posted_date'].dt.month

# Explode the job_skills column and pivot
df_DA_explode = df_DA.explode('job_skills')
df_DA_pivot = df_DA_explode.pivot_table(index= 'job_posted_month_no', columns= 'job_skills', aggfunc= 'size', fill_value= 0)

# sort the skills by count
df_DA_pivot.loc['Total'] = df_DA_pivot.sum()
df_DA_pivot = df_DA_pivot[df_DA_pivot.loc['Total'].sort_values(ascending= False).index]
df_DA_pivot = df_DA_pivot.drop('Total')

# Use month names for plotting
df_DA_pivot = df_DA_pivot.reset_index()
df_DA_pivot['job_posted_month'] = df_DA_pivot['job_posted_month_no'].apply(lambda x: pd.to_datetime(x, format= '%m').strftime('%b'))
df_DA_pivot = df_DA_pivot.set_index('job_posted_month')
df_DA_pivot = df_DA_pivot.drop(columns= 'job_posted_month_no')

# Get the top 5 skills
df_DA_pivot.iloc[:, :5].plot(kind= 'line')

plt.title('Top 5 Skills for Data Analysts per Month')
plt.ylabel('Count')
plt.xlabel('')
plt.show()

# %%
df_DA_pivot
# Out:
# job_skills          sql  excel  python  tableau  power bi     r   sas  \
# job_posted_month
# Jan               11336   8170    6606     5596      4285  3607  3830
# Feb                7947   5772    4751     3936      3307  2576  2634
# Mar                7868   5675    4741     4051      3176  2650  2554
# Apr                7553   5496    4557     3776      3106  2399  2598
# May                6617   4773    4070     3245      2695  2093  1940
# Jun                7584   5724    4707     3812      3275  2442  2174
# Jul                7687   5513    4831     3928      3350  2444  2118
# Aug                8823   6482    5576     4533      3859  2975  2560
# Sep                6829   4886    4229     3446      3118  2146  1880
# Oct                7474   5217    4693     3709      3340  2380  2114
# Nov                6652   4776    4233     3284      3012  2159  1738
# Dec                6058   4376    4196     3139      2857  2125  1858
#
# job_skills        powerpoint  word   sap  ...  angular.js  xamarin  gtx  \
# job_posted_month                          ...
# Jan                     1880  1778  1251  ...           2        0    0
# Feb                     1291  1235   954  ...           0        0    0
# Mar                     1266  1203   892  ...           0        1    0
# Apr                     1190  1177   947  ...           0        0    0
# May                      979   957   851  ...           0        0    0
# Jun                     1173  1237   987  ...           0        0    0
# Jul                     1096  1069   996  ...           0        0    1
# Aug                     1332  1298  1117  ...           0        0    0
# Sep                      944   945   852  ...           0        0    0
# Oct                      955   990   872  ...           0        1    0
# Nov                      894   887   808  ...           0        0    0
# Dec                      822   786   753  ...           0        0    0
#
# job_skills        nuxt.js  ovh  esquisse  suse  capacitor  chainer  msaccess
# job_posted_month
# Jan                     1    0         0     0          1        0         0
# Feb                     0    0         0     0          0        0         0
# Mar                     0    0         0     1          0        0         0
# Apr                     0    1         0     0          0        0         0
# May                     0    0         0     0          0        0         1
# Jun                     0    0         0     0          0        0         0
# Jul                     0    0         0     0          0        0         0
# Aug                     0    0         0     0          0        0         0
# Sep                     0    0         0     0          0        0         0
# Oct                     0    0         0     0          0        0         0
# Nov                     0    0         1     0          0        0         0
# Dec                     0    0         0     0          0        1         0
#
# [12 rows x 235 columns]

# %%
df_DA_pivot.iloc[:, :5].plot(kind= 'line')
plt.show()

# %%
df_DA_pivot.iloc[:, :5].plot(
    kind= 'line',
    linewidth= 4,
    linestyle= ':', # options: '-', '--', '-.', ':'
    colormap= 'viridis', # options: 'viridis', 'plasma', 'inferno', 'magma', 'cividis'
    markersize= 5,
    marker= 'o', # options: 'o', 'x', '+', '*', 's', ',', '.', '1', '2', '3', '4', ...
    figsize= (10, 5)
)
plt.title('Top 5 Skills for Data Analysts per Month')
plt.ylabel('Count')
plt.xlabel('')
plt.show()

# %% [markdown]
# ## Customizing our Scatter plot from `15_Scatter_Plot.ipynb`

# %%
# Explode the 'job_skills' into individual rows
df_exploded = df_DA.explode('job_skills')

# Calculate the average salary and count of job postings per skill
skill_stats = df_exploded.groupby('job_skills').agg(
    median_salary= ('salary_year_avg', 'median'),
    skill_count= ('job_skills', 'count')
)

# Limit to the top skills
skill_count = 20
skill_stats = skill_stats.sort_values(by= 'skill_count', ascending= False).head(skill_count)

skill_stats
# Out:
#             median_salary  skill_count
# job_skills
# sql          92500.000000        92428
# excel        84479.000000        66860
# python       98500.000000        57190
# tableau      95000.000000        46455
# power bi     90000.000000        39380
# r            92527.500000        29996
# sas          90000.000000        27998
# powerpoint   85000.000000        13822
# word         80000.000000        13562
# sap          90000.000000        11280
# azure       100000.000000        10913
# oracle       95000.000000        10387
# aws         100500.000000         9047
# sql server   92150.000000         8288
# go           90000.000000         7905
# flow         94450.000000         7259
# vba          90000.000000         6841
# looker      104000.000000         6259
# snowflake   110240.109375         6178
# qlik        100000.000000         5681

# %%
skill_stats.plot(kind= 'scatter', x= 'skill_count', y= 'median_salary')

for i, txt in enumerate(skill_stats.index):
    plt.text(skill_stats['skill_count'].iloc[i], skill_stats['median_salary'].iloc[i], txt)

plt.xlabel('Count of Job Postings')
plt.ylabel('Median Yearly Salary')
plt.title(f'Salary vs. Count of Job Postings for Top {skill_count} Skills')
plt.tight_layout()
plt.show()

# %%
from adjustText import adjust_text

skill_stats.plot(kind= 'scatter', x= 'skill_count', y= 'median_salary')

texts= []
for i, txt in enumerate(skill_stats.index):
    texts.append(plt.text(skill_stats['skill_count'].iloc[i], skill_stats['median_salary'].iloc[i], txt))

adjust_text(texts, arrowprops= dict(arrowstyle= "->", color= 'gray', lw= 1))

plt.xlabel('Count of Job Postings')
plt.ylabel('Median Yearly Salary')
plt.title(f'Salary vs. Count of Job Postings for Top {skill_count} Skills')
plt.tight_layout()
plt.show()

# %%
#fig, ax = plt.subplots()

skill_stats.plot(kind= 'scatter', x= 'skill_count', y= 'median_salary')

texts= []
for i, txt in enumerate(skill_stats.index):
    texts.append(plt.text(skill_stats['skill_count'].iloc[i], skill_stats['median_salary'].iloc[i], txt))
adjust_text(texts, arrowprops= dict(arrowstyle= "->", color= 'gray', lw= 1))

ax = plt.gca()
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda y, pos: f'${int(y/1000)}K'))

# Set axis labels, title, and legend
plt.xlabel('Count of Job Postings')
plt.ylabel('Median Yearly Salary')
plt.title(f'Salary vs. Count of Job Postings for Top {skill_count} Skills')

# Adjust layout and display the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as mticker

# Setting the style
sns.set(style= "darkgrid")
plt.style.use("dark_background")

# Scatter plot
skill_stats.plot(kind= 'scatter', x= 'skill_count', y='median_salary')

# Adding text annotations
for i, txt in enumerate(skill_stats.index):
    plt.text(skill_stats['skill_count'].iloc[i], skill_stats['median_salary'].iloc[i], txt)

# Formatting the x-axis with commas
plt.gca().xaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f'{int(x):,}'))

# Adding labels and title
plt.xlabel('Count of Job Postings')
plt.ylabel('Median Yearly Salary')
plt.title(f'Salary vs. Count of Job Postings for Top {skill_count} Skills')

# Adjust layout
plt.tight_layout()

# Show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import matplotlib.pyplot as plt
#       2 import seaborn as sns
#       3 import matplotlib.ticker as mticker
#
# File c:\Users\hp\anaconda3\envs\python_project\Lib\site-packages\matplotlib\pyplot.py:62
#      60 from matplotlib import get_backend as get_backend, rcParams as rcParams
#      61 from matplotlib import cm as cm  # noqa: F401
# ---> 62 from matplotlib import style as style  # noqa: F401
#      63 from matplotlib import _pylab_helpers
#      64 from matplotlib import interactive  # noqa: F401
#
# File c:\Users\hp\anaconda3\envs\python_project\Lib\site-packages\matplotlib\style\__init__.py:1
# ----> 1 from .core import available, context, library, reload_library, use
#       4 __all__ = ["available", "context", "library", "reload_library", "use"]
#
# File c:\Users\hp\anaconda3\envs\python_project\Lib\site-packages\matplotlib\style\core.py:225
#     220     return main_dict
#     223 # Load style library
#     224 # ==================
# --> 225 _base_library = read_style_directory(BASE_LIBRARY_PATH)
#     226 library = {}
#     227 available = []
#
# File c:\Users\hp\anaconda3\envs\python_project\Lib\site-packages\matplotlib\style\core.py:203, in read_style_directory(style_dir)
#     201 for path in Path(style_dir).glob(f"*.{STYLE_EXTENSION}"):
#     202     with warnings.catch_warnings(record=True) as warns:
# --> 203         styles[path.stem] = _rc_params_in_file(path)
#     204     for w in warns:
#     205         _log.warning('In %s: %s', path, w.message)
#
# File c:\Users\hp\anaconda3\envs\python_project\Lib\site-packages\matplotlib\__init__.py:906, in _rc_params_in_file(fname, transform, fail_on_error)
#     904 import matplotlib as mpl
#     905 rc_temp = {}
# --> 906 with _open_file_or_url(fname) as fd:
#     907     try:
#     908         for line_no, line in enumerate(fd, 1):
#
# File c:\Users\hp\anaconda3\envs\python_project\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File c:\Users\hp\anaconda3\envs\python_project\Lib\site-packages\matplotlib\__init__.py:883, in _open_file_or_url(fname)
#     881 else:
#     882     fname = os.path.expanduser(fname)
# --> 883     with open(fname, encoding='utf-8') as f:
#     884         yield f
#
# File <frozen codecs>:309, in __init__(self, errors)
#
# KeyboardInterrupt:
